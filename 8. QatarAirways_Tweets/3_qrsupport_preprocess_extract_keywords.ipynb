# %%
import ast
import warnings
import textwrap

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.auto import tqdm

# NLTK packages
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Spacy
import spacy

warnings.filterwarnings("ignore")

# For better visualizations
sns.set(style="ticks", palette="muted", color_codes=True)

plt.rcParams['axes.labelsize'] = 15
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['font.weight'] = 'bold'

# downloading corpus
nltk.download('stopwords')
nltk.download('punkt')

stopwords = set(stopwords.words("english"))

# Remove 'not' from stopword list
stopwords.remove('not')

# Load the spaCy English model
# https://github.com/explosion/spaCy/issues/6498
nlp = spacy.load("en_core_web_lg", disable=["parser", 'ner'])
# nlp.add_pipe('sentencizer')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def wrap_text(text):
    return textwrap.fill(text, width=85)

# %%
df=pd.read_csv("qatarairways_tweets_sentiments.csv", parse_dates=['date'])

# %%
df.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/juliet_gough/status/174158...
# 1  https://twitter.com/theamaeestales/status/1741...
# 2  https://twitter.com/rvvaradan/status/174143019...
# 3  https://twitter.com/ManojKa15016293/status/174...
# 4  https://twitter.com/nkonialidis/status/1741377...
#
#                                                 text  \
# 0  It was fantastic service onboard. I'm so impre...
# 1  @qrsupport is there a problem with your app? I...
# 2  I have reported the incident. Hoping to get a ...
# 3  Not settling dues for more than 3 years . Appr...
# 4  Kindly communicate better about the upcoming r...
#
#                        date  Likes  Comments hashtags  \
# 0 2023-12-31 22:23:00+00:00      0         0       []
# 1 2023-12-31 19:51:00+00:00      0         0       []
# 2 2023-12-31 12:04:00+00:00      1         3       []
# 3 2023-12-31 10:19:00+00:00      2         2       []
# 4 2023-12-31 08:34:00+00:00      1         3       []
#
#                                     sentiment
# 0   {'label': 'positive', 'score': 0.9895235}
# 1   {'label': 'negative', 'score': 0.7817413}
# 2    {'label': 'neutral', 'score': 0.6894269}
# 3  {'label': 'positive', 'score': 0.83495665}
# 4   {'label': 'neutral', 'score': 0.82786304}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65793 entries, 0 to 65792
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   link       65793 non-null  object
#  1   text       65793 non-null  object
#  2   date       65793 non-null  datetime64[ns, UTC]
#  3   Likes      65793 non-null  int64
#  4   Comments   65793 non-null  int64
#  5   hashtags   65793 non-null  object
#  6   sentiment  65793 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(2), object(4)
# memory usage: 3.5+ MB

# %% [markdown]
# # Preprocess Text for EDA

# %%
# https://github.com/kootenpv/contractions
import contractions

eg_str = df.loc[199, 'text']
print(wrap_text(eg_str))
print()
print(wrap_text(contractions.fix(eg_str)))
# Out:
# @qrsupport @qatarairways I’m genuinely disappointed that my exist seat that I booked
# for my 16hrs outward flight tomorrow to LAX was given to another passenger when I
# only changed the date of my return flight. I’ve been a privilege member for 10+
# years. Wasn’t offered a solution.
#
# @qrsupport @qatarairways I am genuinely disappointed that my exist seat that I booked
# for my 16hrs outward flight tomorrow to LAX was given to another passenger when I
# only changed the date of my return flight. I have been a privilege member for 10+
# years. Was not offered a solution.

# %%
# Remove stopwords function
def remove_sw(text):
    tokenized_text = word_tokenize(text)
    # Remove stopwords and those words that is of length<=2
    processed_text = (word for word in tokenized_text if not word in stopwords and len(word) > 2)

    return " ".join(processed_text)

print(wrap_text(eg_str))
print()
print(wrap_text(remove_sw(contractions.fix(eg_str))))
# Out:
# @qrsupport @qatarairways I’m genuinely disappointed that my exist seat that I booked
# for my 16hrs outward flight tomorrow to LAX was given to another passenger when I
# only changed the date of my return flight. I’ve been a privilege member for 10+
# years. Wasn’t offered a solution.
#
# qrsupport qatarairways genuinely disappointed exist seat booked 16hrs outward flight
# tomorrow LAX given another passenger changed date return flight privilege member 10+
# years Was not offered solution

# %%
# Lemmatization
# https://stackoverflow.com/a/75215495/15937542
def lemmatize_pipe(text_col):
    
    docs = nlp.pipe(text_col)
    lemmatized_col = [lemmatize_text_spacy(doc) for doc in docs]

    return lemmatized_col


def lemmatize_text_spacy(doc):

    # Extract lemmatized words
    # The word refunded does not get lemmatized, hence adding this special condition
    lemmatized_words = (token.lemma_ if token.text != "refunded" else "refund" for token in doc)

    # Join the lemmatized words to form the lemmatized text
    lemmatized_text = ' '.join(lemmatized_words)

    return lemmatized_text

print(wrap_text(eg_str))
print()

doc=nlp(remove_sw(contractions.fix(eg_str)))
print(wrap_text(lemmatize_text_spacy(doc)))
# Out:
# @qrsupport @qatarairways I’m genuinely disappointed that my exist seat that I booked
# for my 16hrs outward flight tomorrow to LAX was given to another passenger when I
# only changed the date of my return flight. I’ve been a privilege member for 10+
# years. Wasn’t offered a solution.
#
# qrsupport qatarairways genuinely disappointed exist seat book 16hrs outward flight
# tomorrow LAX give another passenger change date return flight privilege member 10 +
# year be not offer solution

# %%
df = (
    df.drop_duplicates(subset='text', ignore_index=True)
    .assign(
        
        # Extract usernames
        users=lambda x: x['link'].str.extract(r'twitter\.com/(.*?)/status', expand=False),

        # For the `cleaned_text` column, first the `text` undergoes all preprocessing steps such as
        # removing user hanldes, urls, remove empty spaces, stopwords, etc.
        # Finally, the whole proprocessed `text` column is then inputted into the 
        # "lemmatize_pipe" function to process lemmatization quickly.
        cleaned_text=lambda x: lemmatize_pipe(
            # lower case
            x['text'].str.lower()
            
            # Remove all userhandles
            .str.replace(r'@\w+', ' ', regex=True)
            
            # Remove all url links
            .str.replace(r'https*.*? *|www\..*? *|bit\..*? *', " ", 
                         regex=True)

            # Apply Contractions function
            .apply(contractions.fix)

            # Remove everything other characters extept alphabets
            .str.replace(r'[^a-z]', ' ', regex=True)

            # Remove all extra spaces
            .str.replace('\s+', " ", regex=True)

            # Remove leading and trailing spaces
            .str.strip()

            # Remove stopwords
            .apply(remove_sw)
            ),
        
        # Create new column that contain sentiment label
        sntmnt_lbl=lambda x: (x['sentiment']
                        .apply(ast.literal_eval)
                        .apply(lambda x: x['label'])),

        # Create new column that contain score for sentiment label
        score=lambda x: (x['sentiment']
                        .apply(ast.literal_eval)
                        .apply(lambda x: x['score'])),
    )
    # drop sentiment column
    .drop('sentiment', axis=1)

    # remove those rows with just empty text after preprocessing
    .loc[lambda x:x['cleaned_text'].ne('')]
    .reset_index(drop=True)
)

df.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/juliet_gough/status/174158...
# 1  https://twitter.com/theamaeestales/status/1741...
# 2  https://twitter.com/rvvaradan/status/174143019...
# 3  https://twitter.com/ManojKa15016293/status/174...
# 4  https://twitter.com/nkonialidis/status/1741377...
#
#                                                 text  \
# 0  It was fantastic service onboard. I'm so impre...
# 1  @qrsupport is there a problem with your app? I...
# 2  I have reported the incident. Hoping to get a ...
# 3  Not settling dues for more than 3 years . Appr...
# 4  Kindly communicate better about the upcoming r...
#
#                        date  Likes  Comments hashtags            users  \
# 0 2023-12-31 22:23:00+00:00      0         0       []     juliet_gough
# 1 2023-12-31 19:51:00+00:00      0         0       []   theamaeestales
# 2 2023-12-31 12:04:00+00:00      1         3       []        rvvaradan
# 3 2023-12-31 10:19:00+00:00      2         2       []  ManojKa15016293
# 4 2023-12-31 08:34:00+00:00      1         3       []      nkonialidis
#
#                                         cleaned_text sntmnt_lbl     score
# 0          fantastic service onboard impressed thank   positive  0.989524
# 1                      problem app not login account   negative  0.781741
# 2           report incident hope get resolution soon    neutral  0.689427
# 3  not settle due year appreciate emirates airway...   positive  0.834957
# 4         kindly communicate well upcoming rebooking    neutral  0.827863

# %%
# Compare original vs final preprocessed text
print(wrap_text(eg_str))
print()
print(wrap_text(df.loc[193, 'cleaned_text']))
# Out:
# @qrsupport @qatarairways I’m genuinely disappointed that my exist seat that I booked
# for my 16hrs outward flight tomorrow to LAX was given to another passenger when I
# only changed the date of my return flight. I’ve been a privilege member for 10+
# years. Wasn’t offered a solution.
#
# genuinely disappointed exist seat book hrs outward flight tomorrow lax give another
# passenger change date return flight privilege member year not offer solution

# %% [markdown]
# ## Keyword/phrase Extraction

# %% [markdown]
# ### KeyBert

# %%
from keybert import KeyBERT
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer

sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
vectorizer = CountVectorizer(max_df=0.7, stop_words='english', ngram_range=(1, 2))


model = KeyBERT(model=sentence_model)

def extract_keywords(texts):

    kw_list = model.extract_keywords(
        texts,
        vectorizer=vectorizer,
        top_n=3,
        use_mmr=True,
        diversity=0.7
    )

    keywords=[",".join((k[0] for k in kw_tup if "qatar" not in k)) for kw_tup in kw_list]
    
    return keywords
# Out:
# WARNING:tensorflow:From c:\Users\USER\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
batch_size=64
nbr_of_batches=int(np.ceil(len(df)/batch_size))

df_batches = np.array_split(df['cleaned_text'].to_list(), nbr_of_batches)

keyword_list=[]

for batch in tqdm(df_batches):
    keywords_from_batch = extract_keywords(texts=batch)
    keyword_list.extend(keywords_from_batch)
# Out:
#   0%|          | 0/991 [00:00<?, ?it/s]

# %%
keyword_list
# Out:
# ['service onboard,fantastic service,impressed thank',
#  'app login,account,problem',
#  'report incident,hope resolution,soon',
#  'appreciate emirates,settle year,airways respect',
#  'upcoming rebooking,kindly communicate,communicate upcoming',
#  'cancel flight,live chat,believe slowness',
#  'unable log,flight,require character',
#  'airline hope,trip advantage,new customer',
#  'file ref,send file,thank send',
#  'flight kathmandu,assistance message,miss',
#  'baggage final,doh continue,member check',
#  'seat pay,toddler jan,bulk row',
#  'check airport,service cape,long srop',
#  'yes response,till day,yes',
#  'kindly respond,kindly,respond',
#  'flight doha,compensation delay,right html',
#  'seat airport,month advance,exit row',
#  'help qatarairway,check mother,center number',
#  'share',
#  'booking qatar,remark club,add baby',
#  'qatar airway,jan twice,confirm mean',
#  'qatar airway,jan twice,confirm mean',
#  'october bank,receive email,information twice',
#  'stroller airport,infant,website say',
#  'thailand transfer,madrid terminal,pick luggage',
#  'phone qatar,sign privilege,hit update',
#  'team duff,honored receive,doha lagos',
#  'qatar airways,receive day,trip srilanka',
#  'qatar airways,receive day,trip srilanka',
#  'smart scheduling,scheduling,smart',
#  'look',
#  'claim support,send day,ago despite',
#  'baggage seat,condition report,safe',
#  'look dms,pls,look',
#  'ticket booking,middle need,include',
#  'platinum member,reply airport,everyday week',
#  'flight schedule,let hook,minor cause',
#  'link qatarairway,grievance distract,post',
#  'attempt refund,illness pass',
#  'qatar airway,sell vulnerable,infamous cowboy',
#  'check suggest,suggest,check',
#  'free qatar,schedule change,rip people',
#  'qatar cancel,schedule change,agent india',
#  'help qatar,schedule change,airway',
#  'business book,heathrow refuse,support lie',
#  'hour support,support rubbish,rubbish',
#  'message qatarairway,link stall,solve problem',
#  'wait refund,reach chat,despite',
#  'answer phone,response communication,day update',
#  'bag inbox,marry today,update embrace',
#  'consumer court,sleep raise,share time',
#  'luggage chat,payment advise,try',
#  'acceptable trauma,update,cause',
#  'doha hrs,greeting transit,eligible',
#  'touch channel,response,know',
#  'update bag,locate comms,team karachi',
#  'international flight,usa india,provide field',
#  'reply month,treat customer,ago think',
#  'really team,team,really',
#  'git reply,complaint month,airline make',
#  'specific email,address,specific',
#  'hotel layover,explore city,hrs',
#  'doha transit,lhe gyd,guide',
#  'experience different,offer juice,journey bad',
#  'flight credit,orelse luggage,resolve issue',
#  'lose luggage,action,weere valuable',
#  'travel experience,problem behavior,far worst',
#  'estimate timeline,bag issue,prevent locate',
#  'share feedback,help share,help',
#  'update department,department elevate,elevate',
#  'chat support,refund despite,time receive',
#  'sandwich wake,crew serve,fly today',
#  'whatsapp support,number qatar,suggest path',
#  'morning happy,christmas hope,family good',
#  'infant clothe,lose bag,unhelpful recommend',
#  'website lock,access booking,flight tomorrow',
#  'delay mother,boarding pass,christmas family',
#  'luggage prebook,rsqk aware,allow add',
#  'doha delay,stick dublin,lock app',
#  'ajithakarthika ticket,reschedule charge,clt confirm',
#  'contact joke,update contact,update',
#  'account lock,unlock,hrs happen',
#  'check',
#  'possible answer,possible,answer',
#  'bad aireay,aireay,bad',
#  'flight doha,indigo overbooked,staff helpful',
#  'cancel flight,speak customer,relation rep',
#  'change password,try log,error allow',
#  'report qatar,damage baggage,office stop',
#  'delay flight,pls check,hope',
#  'iad delay,facility refreshing,flight doh',
#  'book flight,log month,want pay',
#  'doha suppose,tell bag,file miss',
#  'merry christmas,new,year',
#  'qatar flight,refund need,delay',
#  'laptop bag,weigh coat,allow',
#  'cas crm,star service,long team',
#  'investigation refunding,qatar need,value total',
#  'connection doha,ask file,dxb',
#  'thank talk,talk,thank',
#  'cancel ticket,platinum member,late deduct',
#  'payment card,technical issue,flight stopover',
#  'zambia flight,update stick,develop technical',
#  'transit visa,nationality,require obtain',
#  'transit doha,need visa,able',
#  'luggage condition,chile change,return pay',
#  'website phone,hack victim,line',
#  'website phone,phone line,line hack',
#  'check',
#  'qatarairway scamme,extra luggage,mother',
#  'case number,number need,need',
#  'india doha,airtag check,couple question',
#  'respect hearing,week hard,whe issue',
#  'app late,reset affective,include receive',
#  'qatar change,purchase ticket,talk',
#  'land doha,desk baggage,separate pnr',
#  'try log,code code,say send',
#  'change flight,matter date,manage book',
#  'thank',
#  'feedback unbanjoshcahill,customer feedback,real customer',
#  'come qatar,miss avio,book flight',
#  'fly future,thank,certainly',
#  'kindly requested,thank,info',
#  'airline world,block customer,glitch portal',
#  'sorry message,message,sorry',
#  'terrible airline,terrible,say',
#  'deadline fix,discount flight,long website',
#  'request refund,search website,number flight',
#  'wait resolve,worry,wait',
#  'chatbot explain,times problem,try day',
#  'madrid doha,lose baggage,help query',
#  'expect response,satisfied feedback,finally',
#  'message booking,booking reference,reference number',
#  'tweet hear,send yesterday,response',
#  'belfast flight,luggage website,pay add',
#  'send',
#  'fly qatar,force customer,honor',
#  'reservation refund,leader quality,nearly month',
#  'dubai flood,write gospel,incompetence mankind',
#  'imam mahdi,support bring,california mexico',
#  'imam mahdi,message,return ignore',
#  'send',
#  'booking reference,hey share,number',
#  'cas crm,number complaint,answer escalate',
#  'refuse help,lie,help',
#  'care form,refund day,everyday regard',
#  'advice warn,wrong fly,like',
#  'allow reschedule,email pfcdoh,service fee',
#  'compassion qatarnationalday,benefit year,end service',
#  'unbanjoshcahill',
#  'log account,account,log',
#  '',
#  'thank confirmation,confirmation,thank',
#  'luggage allowance,sri,item use',
#  'accord indigo,booking reference,rhohxq code',
#  'week dme,dme,week',
#  'qatar booking,office johannesburg,oryx',
#  'booking eticket,copy flight,request copy',
#  'unban josh,youtu qysdgg,cahill',
#  'month avios,sector flight,tell patient',
#  'share',
#  'baggage allowance,lhr blr',
#  'france embassy,email confirmation,issue boarding',
#  'await refund,pnr,tat day',
#  'article flight,info website,technically loose',
#  'forget wallet,doha baggage,desk staff',
#  'case number,look,doubt bad',
#  'torture qatar,airway kid,hrs',
#  'aviation news,restart cwl,provide',
#  'transit mother,upcoming layover,hour kindly',
#  'iata law,customer strand,land hope',
#  'cash accept,pwople look,biko',
#  'iberia qatar,sharing complaint,moment land',
#  'thank',
#  'thank',
#  'ban bribe,flight reviewer,service way',
#  'say month,month,say',
#  'kathmandu doha,hand luggage,stop vaporizer',
#  'unbanjoshcahill rehire,rehire crew,crew',
#  'expect refund,expect,refund',
#  'dmed info,reply,thank',
#  'normally reply,reply,long',
#  'submit response,submit,response',
#  'flight date,cancel provide,record locator',
#  'business class,experience,horrible',
#  'feedback option,respond,site',
#  'doha row,baggage relate,ldn start',
#  'book flight,payment personal,different server',
#  'complaint provide,link wait,possible bitter',
#  'great send,send thank,thank',
#  'cas,prompt response,week ago',
#  'receive communication,class airline,wait week',
#  'reservation make,chase ultimate,infant exist',
#  'lax passenger,change date,book hrs',
#  'need year,yes really,really need',
#  'final airline,week say,book entire',
#  'iata procedure,point main,yes kindly',
#  'seat headrest,fly dfw,fix make',
#  'multiple attempt,attempt,help',
#  'online check,try,work help',
#  'mean pyjama,flight hour,thank',
#  'awkward',
#  'night flight,flight,night',
#  'value traveller,bet treat,contact sort',
#  'flight buenos,avio require,appreciate',
#  'account graduation,privilege club,unfair promise',
#  'extrabag snack,passenger europe,economy class',
#  'cas crm,claim payment,mandatory document',
#  'carry qatar,change clothe,gym doh',
#  'day response,day,response',
#  'check record,useless people,send',
#  'bother dme,read message,bother',
#  'lie qatar,lie lie,airline',
#  'thank successfully,successfully,thank',
#  'lose luggage,month resolution,clearly',
#  'direct message,reply,reach',
#  'bag contact,try whatsapp,lose day',
#  'email bounce,support category,struggle',
#  'indigo assist,say contact,assist say',
#  'possession document,hello status,resolve matter',
#  'flight cancel,pet crate,wish rebook',
#  'course standby,provide,course',
#  'long say,long,say',
#  'medical emergency,atq sfo,postpone day',
#  'check thank,check,thank',
#  'response promise,month want,lie people',
#  'flight unavailable,app website,international december',
#  'time respond,respond,numerous',
#  'stop game,check email,info',
#  'quality template,responsibility answer,baggage hour',
#  'avio credit,handler promise,sort miss',
#  'resolve dme,stop post,week',
#  'service platinum,star,imagine',
#  'refund,platinum member,airline shameful',
#  'luggage transfer,hrs connection,day happen',
#  'reply dms,dms week,week',
#  'long issue,post channel,unresolved',
#  'enter date,birth infant,update manage',
#  'thank send,send,thank',
#  'flight icn,february reservation,number kqgnux',
#  'booking flight,phuket belfast,business class',
#  'baggage delay,business day,compensation',
#  'thank',
#  'flight qatar,onboard help,wife kid',
#  'help qatarairway,wife kid,frustrate onboard',
#  'inbound flight,screen turn,say sorry',
#  'luggage tag,zip code,submit request',
#  'bahrain doha,business class,client fly',
#  'day dms,day,accomplish',
#  'hope rectify,rectify hear,hear august',
#  'luggage delay,contact qatar,whatsapp live',
#  'bag qatar,place scan,confirm',
#  'email prematurely,prematurely,send',
#  'booking confirmation,iub bag,month resolve',
#  'refund money,actually fly,refuse',
#  'stand customer,boarding pass,counter hour',
#  'passport renewal,lankan,fly time',
#  'team respond,gentleman whatsapp,relaxed baggage',
#  'check dms,plz,reply',
#  'service hospitality,great trust,reach counter',
#  'check case,case,check',
#  'harassment delay,refund normal,touch usdot',
#  'respond message,message,respond',
#  'receive bag,delay doha,filing claim',
#  'frustrated customer,flight compensation,class upgrade',
#  'qatar airways,offload passenger,service standard',
#  'adjust gap,clot flight,usa saudi',
#  'reservation refund,submit website,long expect',
#  'refund',
#  'kindly dms,dms,kindly',
#  'check flight,message reply,saturday',
#  'respond thank,respond,thank',
#  'isolate incident,application eager,hear hopefully',
#  'wifi code,response qatar,away',
#  'reimbursement flight,delay hrs,hotel meal',
#  'high hope,month able,past',
#  'case victim,say month,world press',
#  'thank',
#  'fly christmas,special make,kid feel',
#  'definitely end,end,definitely',
#  'thank send,send,thank',
#  'lot care,care shit,shit',
#  'seat map,try select,load say',
#  'respond thank,respond,thank',
#  'change registered,log privilege,reason speak',
#  'luggage miss,travel qatar,ord amr',
#  'qatar airways,delay drama,cancel',
#  'validity month,plan transit,affect',
#  'answer money,want,answer',
#  'message qatarairway,reflection incompetence,pasted text',
#  'avio shame,company email,time issue',
#  '',
#  'issue voucher,receive procedure,postpone flight',
#  'qatar airways,outcome issue,contact directly',
#  'seat book,price secure,sort account',
#  'action',
#  'action time,time pass,pass',
#  'meal paneer,qatar think,pick option',
#  'airtag allow,hand baggage,allow check',
#  'message thank,send,thank',
#  'make refund,nigeria,woman sell',
#  'refund customerservice,policy say,process day',
#  'thank',
#  'guess figure,figure anymore,anymore',
#  'fly qatar,airway,fly',
#  'fly airline,drain privilege,customer service',
#  'update reach,pls,directly',
#  'stress responsibility,suffer stress,suffer',
#  'baggage charging,stress mom,stop mislead',
#  'qanta flight,point reduction,look think',
#  'christmas favour,cost ask,look nearer',
#  'doha rain,live status,chennai chennai',
#  'send aswell,yes sorry,aswell',
#  'lose luggage,try locate,day',
#  'ngg pnr,departure chennai,tell reschedule',
#  'worry luggage,worry,come',
#  'update maa,schedule airport,decemeber app',
#  'send',
#  'intentionally respond,intentionally,respond',
#  'airline holding,month multiple,follow',
#  'flight chennai,doha doh,maa',
#  'share hope,share,resolve issue',
#  'luggage wrap,reply question,plan pay',
#  'club account,wifi flight,believe entitle',
#  'respond qatar,day,respond',
#  'qatar airway,dad passport,negligent unresponsive',
#  'son suitcase,send wait,wait',
#  'clothe wear,trek son,wait reply',
#  'hotel clothe,wear trek,know son',
#  'jetkids bedbox,flight accompany,year old',
#  'dmed day,dmed,day',
#  'thank',
#  'question refund,post concern,initiate day',
#  'bag travel,support ahmedabad,allow laptop',
#  'qatar airways,bring guest,bkk',
#  'son bag,retrieve return,look forward',
#  'clothe thank,sort tomorrow,son',
#  'update complaint,response update,response',
#  'note complaint,month previous,incompetence loss',
#  'settlement wrong,break luggage,service recommend',
#  'munich airport,tomorrow pay,train busses',
#  'send',
#  'doha schedule,pax inbound,nurse head',
#  'confirmation refund,receive email,need file',
#  'flight unable,process request,check tomorrow',
#  'cancel booking,day vhyszi,guy send',
#  'lhr airport,eligible fast,business class',
#  'pay qatarairway,damage bag,claim work',
#  'qatar qatarairways,bag damage,evidence submit',
#  'reschedule flight,hrs success,manually calculate',
#  'handling complaint,aviation authority,number deal',
#  'manchester arrive,leave baggage,update business',
#  'breakdown refund,provide detailed,request thank',
#  'wrong settlement,break luggage,month send',
#  'flight nigeria,receive mum,support lie',
#  'reply seat,thank wait,allotment',
#  'wait',
#  'check',
#  'transfer doha,hangzou delay,complaint traveeling',
#  'share',
#  'make seat,family travel,atleast basic',
#  'share',
#  'india helpline,modification flight,tonight',
#  'hour response,terrible customer,service',
#  'dmed minute,response team,ago',
#  'munich airport,announce cancel,technology weather',
#  'kurdish email,money kurdish,money',
#  'doha delay,flight paris,guarantee make',
#  'certainly',
#  'wire transfer,compensation offer,high cost',
#  'doha tell,update flight,information',
#  'delay canada,support experience,transfer desk',
#  '',
#  'holiday doha,cancel curfew,leave transfer',
#  'flight doha,doha,flight',
#  'disappointed flight,travel qatar,late stuck',
#  'disappointed flight,wifi voucher,screen work',
#  'seat complaint,month avio,reinstate spend',
#  'time',
#  'response complaint,qatar caa,flight edinburgh',
#  'approve refund,million naira,thank',
#  'trouble log,club payment,say technical',
#  'booking hold,site outage,hrs',
#  'send',
#  'poorcustomerservice discourse,escalation fly,experience deal',
#  'thug liar,short thug,bad short',
#  'turkish airline,gen cide,replace product',
#  'qatar airways,sleep allow,pay upgrade',
#  'send thank,send,thank',
#  'request wheelchair,expect qatar,mother law',
#  'passenger delay,ineffective ground,acceptable compensate',
#  'refund claim,indigo airways,make joint',
#  'compensation usd,account gbp,work bank',
#  'jeddah airport,terminal,south',
#  'qatar offer,usd day,cover clothing',
#  'message send,message,send',
#  'baggage allowance,dhabi qatar,comfort buy',
#  'customer support,sadden issue,resolve month',
#  'transit accommodation,select nationality,website bug',
#  'rude number,karl,speak rep',
#  'faa california,email twitter,wallet leave',
#  'lounge open,mourjan garden,hello gym',
#  'club account,wifi flight,believe entitle',
#  'airline think,february refund,use pay',
#  'check flight,vienna,currently unavailable',
#  'file complaint,know damage,face family',
#  'cardiff airport,start flight,start',
#  'legitimate page,day legal,reach thank',
#  'airport delhi,reach hour,igi',
#  'email include,promise response,seating issue',
#  'luggage maximum,buy extra,piece check',
#  'approve qatar,airline,type thing',
#  'picture baggage,say compensation,guy audacity',
#  'claim compensation,acco meal,destination delhi',
#  'black friday,website work,try',
#  'wish good,absolutely wish,absolutely',
#  'flight divert,abu dhabi,nyc daughter',
#  'pay remittance,free ticket,worth ask',
#  'thank way,thank,way',
#  'available cardiff,book,available',
#  'flight singapore,discount advise,try book',
#  'check nowwww,nowwww,check',
#  'arrival payment,hold hope,essentially link',
#  'lose bag,message resolution,world cup',
#  'thank send,send,thank',
#  'thank',
#  'complaint team,ignore email,point',
#  'layover doha,bind flight,time buy',
#  'response read,contact make,issue generic',
#  'suitcase report,airline refuse,use untrustworthy',
#  'unprofessional untrustworthy,airways break,experience qatar',
#  'layover doha,wife indians,stpc deny',
#  'chat email,connect live,ticket march',
#  'travel qatar,indian passport,stopover hour',
#  'receive baggage,complaint hyderabad,date raise',
#  'customerservice qatarairway,book trust,switch stay',
#  'lose baggage,place compensation,untagge mention',
#  'wheelchair information,ktm flight,treat customer',
#  'include supervisor,cheat case,yash raze',
#  'avenue chat,solution avio,loyalist team',
#  'mumbai hour,strand,resolve',
#  'profit refund,escalate',
#  'point refund,assignment app,treat loyal',
#  'bag qatar,staff refuse,print code',
#  'reference blr,file reference,file',
#  'check luggage,carry shall,hand',
#  'refund issue,reservation,helpful sending',
#  'flight dublin,mumbai day,check',
#  'patience leave,month thank,think',
#  'mail reply,receive,day',
#  'refund able,excuse passenger,experience team',
#  'cancel flight,date nov,book hrs',
#  'useless customer,care service,wide world',
#  'useless customer,service,world',
#  'transfer desk,help department,hour tell',
#  'delay baggage,accept complaint,year kenya',
#  'reschedule booking,response qatar,pax',
#  'reschedule departure,advance agent,connect',
#  'arrive melbourne,pnr hgrcsv,group book',
#  'airport wait,bad customer,representative houston',
#  'carry kgs,airport help,ridiculous come',
#  'response',
#  'refund sep,airline surprise,platinum member',
#  'generic sorry,week basically,final away',
#  'doha flight,elderly mother,update disgrace',
#  'comment tell,time similar,way entire',
#  'assist money,refuse money,fly refuse',
#  'send link,previous,work thank',
#  'baggage qatar,kenya,complain',
#  'log qatar,change password,hello team',
#  'air fryer,hand luggage,allow',
#  'office abuja,abuja locate,locate',
#  'unable book,book website,website',
#  'qatarairway try,seat say,pay additional',
#  'awful customer,luggage week,land australia',
#  'claim bag,airport centre,leave doh',
#  'flammable sign,sign,fine',
#  'stopover flight,website work,try day',
#  'fly dublin,mumbai,pay',
#  'provide multiple,multiple time,time',
#  'flight dublin,purchase extra,website different',
#  'queue flight,expect end,walk notice',
#  'automated bag,separate queue,drop option',
#  'delay bag,clothe fair,business trip',
#  'bag qatar,file gva,delay doh',
#  'doha airport,hour delay,food struggle',
#  'jeddah boarding,pass allow,minute delay',
#  'flight home,jan family,girl reward',
#  'tomorrow connection,flight singapore,ensure miss',
#  'footrest qatarairway,tell inflatable,iah',
#  'try hut,unable app,original seat',
#  'parfume flammable,aerosol allow,check baggage',
#  'transit time,hello book,stay provide',
#  'doha check,seat selection,book mahe',
#  'lodge complain,make enquiry,hello',
#  'problem qatar,patient month,tell ask',
#  'customer orientation,like fraudulent,know mean',
#  'doha hour,check open,select seat',
#  'passenger claim,politician bed,profit make',
#  'culture airline,tell alot,wow',
#  'fly doha,bag content,engage mail',
#  'tweet shame,shame,respond',
#  'qatarairways customerserviceissues,journey challenge,disappoint recent',
#  'develop lounge,voucher passenger,drink snack',
#  'reply direct,message,reply',
#  'credit account,qatar case,wry disappointed',
#  'qatar airway,leave airpod,share require',
#  'qatar airway,leave airpod,share require',
#  'avio website,hotel reservation,different channel',
#  'avio refund,hey qatar,make hotel',
#  'flight support,touch far,board',
#  'lodge complaint,lodge,complaint',
#  'promo code,receive email,book flight',
#  'partner airline,avio qpoint,website state',
#  'check machine,bag tag,offer website',
#  'social medium,bad realise,care',
#  'ticket refund,service relate,hour',
#  'page work,unfortunately page,unfortunately',
#  'policy explain,customer write,think coordinated',
#  'hour response,hour,response',
#  'mihirtha,service response,write let',
#  'feedback customer,care day,expedite resolution',
#  'allocate seat,child concern,travel small',
#  'seat flight,small child,able book',
#  'qatar airline,gladly change,thing solve',
#  'change email,request change,long process',
#  'email wrong,qatar airlines,pencil think',
#  'qatar day,send feedback,hello team',
#  'case close,morning operator,make decision',
#  'thief day,money credit,upgrade send',
#  'qatar airway,submit complaint,care frequent',
#  'travel saudi,kenyan national,restriction exist',
#  'argue airline,apologize people,personal experience',
#  'baggage office,today reply,team',
#  'disgraceful qatar,hole suitcase,minor damage',
#  'page claim,expense ignore,january suitcase',
#  'bassinet seat,proof ticket,assign help',
#  'qatar bassinet,travel month,email confirmation',
#  'response time,airline,time',
#  'weigh luggage,istanbul doha,accept fold',
#  'datum breach,agent phone,yes gate',
#  'impersonate customer,chat,appropriately horrible',
#  'passenger cas,book connect,absolutely sympathy',
#  'flight kolkata,sleep hour,refuse compensate',
#  'wait refund,refund,wait',
#  'parent flight,iad send,depart doh',
#  'qatar purchase,layover seattle,deny ridiculous',
#  'premium lounge,upgrade business,class awful',
#  'lie horrible,incompetence,company clear',
#  'flight voucher,cost,swap',
#  'let law,say,send',
#  'believe law,law law,believe',
#  'wait',
#  'strongly law,hilarious believe,know',
#  'talk incompetence,reply post,exactly',
#  'lose patience,week,wait',
#  'airline claim,disappointed assistance,day queue',
#  'legal matter,problem let,provide guess',
#  'handle baggage,bad customer,service handle',
#  'slow customer,airline boycott,say chase',
#  'know happen,love know,love',
#  'dms send,look dms,kindly look',
#  'husband exhaust,doha airport,poorservice',
#  'compensation hassle,absolutely unqualified,need',
#  'wait reply,thank wait,thank',
#  'hyderabad flight,divert bahrain,parent start',
#  'flight date,unable change,agent',
#  'provide welfare,provide,people',
#  'provide watwr,wait airport,hour yiu',
#  'flight leave,poor,help',
#  'qatarairway misplace,bag arrive,month toddler',
#  'people',
#  'bahaha line,line agree,agree',
#  'send original,original thank,thank',
#  'try response,help,try',
#  'dms chat,try support,work point',
#  'jfk doh,divert bah,onboarding luggage',
#  'airport confirm,seat assignment,pick date',
#  'baggage delay,dfw qatar,claim raise',
#  'clock care,congratulation family,relative require',
#  'reply resolution,stil wait,reply',
#  '',
#  'email upset,customer ignore,hello answer',
#  'disagree nicky,enjoy fly,suppose happy',
#  'scam qatar,fluff letter,country employee',
#  'share number,share,number',
#  'account qatar,try link,technical ticket',
#  'send update,update receive,receive',
#  'date money,tired bullshit,specific',
#  'ticket lagos,issue issue,guy piss',
#  'qatar respond,offer support,twitter account',
#  'newcastle doha,flight newcastle,introduce flight',
#  'qatarairways shamble,claim month,online chat',
#  'update case,complaint,week raise',
#  'delay confirm,doh delay,doh',
#  'save manchester,joos,drop race',
#  'qatar airway,respond email,query remain',
#  'customerservice qatarairway,agent fail,resolution cancellation',
#  'airline qatarairway,service communication,video proof',
#  'check airport,drop web,mean fast',
#  'book ticket,layover,provide information',
#  'layover jfk,booking delhi,newyork guy',
#  'send thank,send,thank',
#  'book connect,airport country,mention require',
#  'layover doha,canada visa,reservation delhi',
#  'avio rise,upgrade doha,explain rate',
#  'doha cardiff,regard resume,update',
#  'delhi flight,vegetarian meal,preference set',
#  'response day,response,day',
#  'zam water,airport allow,cover way',
#  'baggage damage,try report,discover home',
#  'fly doha,hanoi promise,turn tomorrow',
#  'laptop bag,amsterdam jakarta,economy flight',
#  '',
#  'seat change,barcelona counter,flight riyadh',
#  'resolve complaint,bother,resolve',
#  'deal complaint,bother,deal',
#  'bother resolve,resolve,bother',
#  'refuse reimburse,flight voucher,point make',
#  'cancel flight,voucher use,money refuse',
#  'qatar disaster,suitcase send,day compensation',
#  'baggage claim,wait line,pende year',
#  'baggage claim,minute line,quality service',
#  'send thank,send,thank',
#  'week feed,feed handle,handle legit',
#  'qatar compensation,delay luggage,struggle day',
#  'delay luggage,airway compensation',
#  'phone steal,new address,employee',
#  'compensation luggage,accord warsaw,lose day',
#  'respond',
#  'unable number,respond facebook,india come',
#  'support baggage,treat customer,process week',
#  'understanding resolve,share datum,confirm',
#  'bas cancel,milan doha,exnq flight',
#  'accept expediting,issue close,month old',
#  'nepal zero,possible train,customer service',
#  'buy lounge,access doha,zrh sin',
#  'trace item,respond email,october fpco',
#  'cancellation penalty,email qatar,process inform',
#  'bag deliver,contact customer,ago amd',
#  'month resolve,message hope,team',
#  'government qatar,officer sailor,court release',
#  'die refund,refund money,money',
#  'check account,cancellation october,feedback form',
#  'lose suitcase,monday compensate,clothe',
#  'hold luggage,hrs meeting,dear wrong',
#  'airline acceptable,process month,really understand',
#  'avio ask,ask,question',
#  'print eticket,digital copy,need',
#  'update complaint,share case,reference number',
#  'avio booking,geneva doha,tell rubbish',
#  'whereabouts luggage,meaningful update,dear',
#  'reach refund,refund,reach',
#  'passport expiry,qatar airways,information save',
#  'flight pandemic,help money,simply',
#  'statement time,reply official,doubt eventually',
#  'tangible feedback,feedback,tangible',
#  'email resolution,round email,day round',
#  'depart terminal,long layover,look lounge',
#  'mla malta,restart service,service',
#  'enter app,website help,book',
#  'reply ticket,fraud try,try hide',
#  'apple airpod,doha,reference dellp',
#  'refund airline,month resolution,scam',
#  'update case,number,team',
#  'cas crm,honor reservation,reply hear',
#  'help refund,big loss,help',
#  'help refund,big financial,guy like',
#  'happen navy,regret warn,india indiannavy',
#  'check',
#  'decline request,date change,conclusion investigation',
#  'saga continue,promise action,norm customer',
#  'greeting flight,experience silver,inform fix',
#  'spam folder,tax invoice,legal consequence',
#  'comment progress,day team,casual approach',
#  'mail apology,compensation loss,month',
#  'baggage report,reply qatar,service mishandle',
#  'baggage department,email customer,service',
#  'baggage delay,refund submit,need',
#  'let know,update,know',
#  'quiet lounge,ask receptionist,direct silver',
#  'booking involve,response message,know reputation',
#  'look resolution,mesage,month countless',
#  'qatar airline,compensation avoid,want step',
#  'close email,form promise,baggage issue',
#  'problem airport,add cuisse,application space',
#  'grant scholarship,scholarship,grant',
#  'reason denial,handle vendor,information social',
#  'cmc expect,response timeline,commit qatarairways',
#  'cert pregnant,flight country,include connect',
#  'redeemable voucher,january possible,change later',
#  'doh jfk,like jnb,post miss',
#  'nigeria complain,distressed disappointed,action team',
#  'long happen,happen till,till',
#  'wait refund,boat,month ask',
#  'help qatar,team lagos,airway complain',
#  'misspell correct,correct thank,thank',
#  'self discovery,flight term,froma website',
#  'connect flight,response website,try',
#  'pay cad,destination country,diligently wait',
#  'resolution touch,priority talk,help',
#  'wrong booking,change,enter',
#  'impersonate customer,team fact,good job',
#  'message support,monitor direct,long handle',
#  'office notice,share address,think continue',
#  'volunteering flight,pende compensation,document multiple',
#  'form settle,definitely form,thank definitely',
#  'damage flight,sadden suitcase,transfer doha',
#  'baggage payment,update lose,hurry time',
#  'booking overbooke,review confirm,bind compensate',
#  'reply ignore,ignore,reply',
#  'response',
#  'apply discount,book app,say',
#  'post help,social channel,obvious case',
#  'investigate escalate,time team,typically week',
#  'send',
#  'busy family,moment thank,certainly wee',
#  'sorrow delay,institution pledge,wheel progress',
#  'support fix,greet,pls kind',
#  'thank',
#  'stress customer,disappointing repeat,difficult inaccessible',
#  'incompetent qrpc,ahmedabad base,priority follow',
#  'qatar airline,stoop low,experience imagine',
#  'end refund,prepare court,hope help',
#  'tax invoice,september september,request',
#  'service awful,mon contact,try time',
#  'staff nigerian,time staff,waste time',
#  'arrive doha,sit,yesterday',
#  'receive bag,update insulation,manager director',
#  'bag hour,know,good',
#  'excellent service,thank,excellent',
#  'airline threaten,remove family,website form',
#  'wind email,say sorry,shocking',
#  'flight resolve,thank board,quick response',
#  'layover deny,guy reschedule,accommodation',
#  'refund second,board flight,book fresh',
#  'process refund,inform issue,nov long',
#  'reply',
#  'booking overbooke,bind compensate,care response',
#  'booking overbooke,bind compensate,care response',
#  'booking overbooke,bind compensate,deny',
#  'travelissue qatarairways,dry pay,hope resolution',
#  'good airway,david genuinely,confuse',
#  'whatsapp qatar,send,airways',
#  'reach',
#  'penalty charge,increase day,pathetic service',
#  'email complaint,deny boarding,borges qatar',
#  'case fraudulent,activity customer,pure',
#  'use japanese,ticket warn,write address',
#  'bag possession,sign check,day',
#  'bot remotely,lack customer,funny authentic',
#  'hamed airport,decision contact,immediately make',
#  'qatar airway,unfortunately ground,professional response',
#  'qatar airway,information fault,tiring run',
#  'catch flight,service refuse,rush',
#  'qatar airways,response refund,break',
#  'doha time,muscat plan,make connect',
#  'miss flight,run gate,sad trust',
#  'joke compensation,compensation mean,mean',
#  'bot believe,bot,believe',
#  'email patience,qatar team,actual honest',
#  'issue refund,monie approve,regard travel',
#  'qatar say,mediocre service,wind email',
#  'avio credit,appear account,flight day',
#  'qrsupport qatarairways,fraud trauma,team hide',
#  'dmed',
#  'incompetent unprofessional,reference reclaim,baggage day',
#  'check',
#  'right away,thank,right',
#  'kathmandu airport,complaint exist,number track',
#  'refuse refund,use month,boarding',
#  'plane send,address phone,kindly',
#  'typical sorry,care anymore,response',
#  'outcome complaint,say investigate,early add',
#  'generic sorry,investigation team,resolve month',
#  'check flight,break try,residence contact',
#  'dme,send screenshot,wait happen',
#  'check selfie,stick tripod,carry cabin',
#  'indigo seat,selection wait,ask talk',
#  'update claim,customer expectation,std response',
#  'yes repeat,scream investigation,understand issue',
#  'safe sound,qatar staff,seattle make',
#  'bad experience,experience,bad',
#  'team response,wait team,wait',
#  'form customer,week typically,team understand',
#  'apologize square,square victimize,victimize',
#  'solve month,problem,solve',
#  'receipt number,fasten process,welcome',
#  'kathmandu online,kindly proceed,accept problem',
#  'share',
#  'mail apologize,pay compensation,case number',
#  'damn',
#  'kuna msafiri,hapa,guy believe',
#  'waive cancellation,cancer complication,dad stage',
#  'lose package,email qatarairway,communicative regard',
#  'cancer warrant,report provide,documentation multiple',
#  'provide refund,work priceline,documentation multiple',
#  'acceptable',
#  'play month,tell july,talk',
#  'obviously human,lol,obviously',
#  'qatar website,change service,fee rule',
#  'post email,avenue disposal,sure happy',
#  'experience qatarairway,timetabling appalling,run connect',
#  'outbound complaint,telephonic conversation,care executive',
#  'fault airline,internal investigation,resolution mail',
#  'book seat,pay additional,class service',
#  'tix thread,unacceptable customerexperience,resolution trash',
#  'flight cancellation,qatar think,inhumane trash',
#  'cancellation dad,ticket priceline,say qatar',
#  'send thank,send,thank',
#  'baggage allowance,plus hand,wednesday',
#  'paypal issue,book ticket,wait reply',
#  'flight change,istanbul sunday,unfortunately accept',
#  'sell ticket,deny boarding,embarrassed refuse',
#  'baggage claim,file october,email toll',
#  'ruin vacation,grievance double,standart',
#  'compensation friend,apologize flight,explain',
#  'expect contact,reply month,cycle',
#  'month aggrievization,solve apologize,right',
#  'investigate result,aggrieving people,judt',
#  'customer care,change convey,sector inbound',
#  'booking cancel,away book,make father',
#  'airport mislead,exclude promo,middle east',
#  'refund money,help people,really seriously',
#  'message suitcase,doha,write direct',
#  'ticket accidentally,edit passenger,birth purchase',
#  'ted awesome,pathetic work,bother till',
#  'november wait,november,wait',
#  'receive case,case reference,reference provide',
#  'thank escalation,worry understandable,reasonable outcome',
#  'dmd info,reference ticket,photo damage',
#  'lie month,post chat,case resolve',
#  'mention form,report mention,thank report',
#  'flight transfer,update complaint,ca lodge',
#  'honeymoon appreciate,mesha darren,damage good',
#  'baggage qatar,submit claim,time limit',
#  'heathrow report,fail issue,reference number',
#  'husband suitcase,london phuket,irreparable damage',
#  'respond',
#  'carry laptop,dublin mumbai,charger check',
#  'sure',
#  'lounge colombo,silver status,website work',
#  'thank prompt,need information,support',
#  'title page,page page,title',
#  'okay',
#  'extend expiry,travel voucher,good day',
#  'retrieve booking,mail documentation,experience support',
#  'customer experience,opposite,matter consider',
#  'impact way,conduct business,offer present',
#  'dirty galley,stow floor,compartment way',
#  'doha delay,plane gate,manchester',
#  'yous reply,reply,yous',
#  'qatari airway,publish sla,claimant timely',
#  'boarding pass,pass,reply check',
#  'struggle check,check,reply',
#  'desk close,close,tell',
#  'yeah',
#  'carry laptop,dublin mumbai,charger check',
#  'customer complaint,reference cas,connect flight',
#  'message response,send,check',
#  'shock customer,reply month,lie travel',
#  'reply',
#  'check flight,dublin wednesday,available let',
#  'ear pain,reschedule flight,air pressure',
#  'online unavailable,hour check,hello flight',
#  'dmed',
#  'response criticism,think use,wait month',
#  'access privilege,club account,issue',
#  'luggage delay,train help,make cost',
#  'notification bag,flight word,file ref',
#  'hand luggage,equal ticket,let know',
#  'change seat,checking airport,fco doh',
#  'change seat,check airport,doh today',
#  'time qatar,prevent travel,attendant say',
#  'flight canada,guy deine,information make',
#  'row staff,skip meal,invisible constantly',
#  'lago luggage,hour landing,kindly look',
#  'thank clarify,clarify,thank',
#  'brussels online,flight leave,good morning',
#  'impersonate rogue,reputation image,make sure',
#  'spammer impersonate,look grievance,approach couple',
#  'airline billion,world good,know think',
#  'book honestly,tough situation,grateful help',
#  'rebook people,service team,huge disappointment',
#  'rush',
#  'refund process,avoid pay,night risk',
#  'cancelation penalty,flight phl,change american',
#  'pitiful company,pitiful,company',
#  'plane refund,change plane,change',
#  'write english,people company,confused',
#  'refund change,airlines doha,yes want',
#  'cancellation fee,credit card,instead',
#  'change airline,help refund,qatar american',
#  'cancel flight,usd fee,family need',
#  'heathrow horrendous,check wait,desk explanation',
#  'wait patiently,patiently people,people',
#  'hope issue,fix,reply',
#  'send guy,send,guy',
#  'hour fast,fast,hour',
#  'surely',
#  '',
#  '',
#  'check midday,service vome,second flight',
#  'flight auckland,hour check,online confise',
#  'second flight,bizzare,basically hour',
#  'flight leave,check,online',
#  'agent month,issue airline,send reply',
#  'reach saigon,bcn sgn,madam plan',
#  'flight qatar,refund,february help',
#  'send fraud,luggage resolution,meta response',
#  'scammer qatar,logo whatsapp,method terminology',
#  'provide thank,provide,thank',
#  'escalation elicit,team unwilling,staff make',
#  'online check,open time,prior',
#  'depart doha,check window,start time',
#  'free qatar,airline think,anybody rip',
#  'lie customer,stop,fuck time',
#  'answer waste,point,time',
#  'staff nigeria,refund understand,blatant liar',
#  'month respond,kind integrity,summon courage',
#  'arrest abuja,fund refund,transit visa',
#  'bad customer,qatar airways,especially nigeria',
#  'unsafe passenger,witness physical,alcohol continue',
#  'dmed',
#  'airline delay,offer compensation,absolutely terrible',
#  'reservation number,airline,sorry provide',
#  'complaint reca,food voucher,zero balance',
#  'avoid complaint,guy avoid,guy',
#  'share response,check,yes',
#  'receive luggage,need,friend',
#  'log privilege,recently advise,able',
#  'number time,number,time',
#  'share long,check email,long check',
#  'airline respond,email,pride good',
#  'contact yesterday,yesterday hear,hear',
#  'situation point,solve,really',
#  'send',
#  'atleast email,team,atleast',
#  'speak chat,guy useless,team want',
#  'file reference,share,number',
#  'airline,avoid issue,diligent work',
#  'resolution traumatize,flight hour,need',
#  'chat whatsapp,option,work response',
#  'bag status,update contact,local office',
#  'baggage file,desk leave,area pir',
#  'acknowledge flight,time covid,make issue',
#  'flight submit,account avio,super wifi',
#  'qatar airway,return member,degrading experience',
#  'experience qatarairway,slow process,reach team',
#  'update phone,number send,otp',
#  'strike answer,sack lie,anybody shit',
#  'send cairo,dfw horrible,book different',
#  'doha delay,route dallas,divert different',
#  'bag arrive,pesawar thank,colud check',
#  'available stroller,carrycot pushchair,accept charge',
#  'reservation cancel,explain numerous,cost make',
#  'mean kindly,prompt reply,afraid understand',
#  'doha faisalabad,airways resume,destination',
#  'solve problem,solve,problem',
#  'thank',
#  'delay happen,night elderly,health safety',
#  'reset password,send otp,need log',
#  'balance nigeria,booking lto,hour',
#  'verify email,link expire,immediately help',
#  'fly qatar,eta resolution,booking base',
#  'note privilege,booking app,appear despite',
#  'log avio,account otp,able fix',
#  'hope resolution,early,thank',
#  'number cas,case reference,reference number',
#  'let week,week,let',
#  'rebooke connect,divert iad,flight statue',
#  'cas reply,morning qatar,try extract',
#  'qatar airway,change suite,date return',
#  'send phone,conversation concern,mental trauma',
#  'send query,query,send',
#  'scam people,support slow,shameonqatarairways',
#  'customer support,ignore problem,october help',
#  'response patient,inconvenience,expedite resolution',
#  'team response,response,team',
#  'update request,update,request',
#  'terrible',
#  'worry pablo,play thousand,like job',
#  'fake account,look fake,look',
#  'qatar account,report waste,fake',
#  'phone discuss,respond,hear reach',
#  'payment option,flight date,nigeria',
#  'disappointment customer,experience hour,provide necessary',
#  'financial scammer,try trick,post repost',
#  'hello',
#  'boycottqatarairway qatarairwaysagainstmentalhealth,trauma anxiety,responsibility compensation',
#  'boycottqatarairway qatarairwaysagainstmentalhealth,space flight,suffocate traumatized',
#  'cash avio,booking fail,deduct book',
#  'reconfirm response,week basically,regret',
#  'qatar airway,problem generic,normal evident',
#  'week generic,response attitude,time waiting',
#  'people lier,story tell,typical old',
#  'hindu meal,doha try,add update',
#  'day customer,approach update,pass time',
#  'qanta airway,money baggage,human right',
#  'qatar airway,decision misrepresentation,provide',
#  ...]

# %%
df['keybert_kw']=keyword_list

# %%
df.loc[:5, ['cleaned_text', 'keybert_kw']]
# Out:
#                                         cleaned_text  \
# 0          fantastic service onboard impressed thank
# 1                      problem app not login account
# 2           report incident hope get resolution soon
# 3  not settle due year appreciate emirates airway...
# 4         kindly communicate well upcoming rebooking
# 5  not believe slowness cancel flight not inform ...
#
#                                           keybert_kw
# 0  service onboard,fantastic service,impressed thank
# 1                          app login,account,problem
# 2               report incident,hope resolution,soon
# 3    appreciate emirates,settle year,airways respect
# 4  upcoming rebooking,kindly communicate,communic...
# 5           cancel flight,live chat,believe slowness

# %% [markdown]
# ### Yake

# %%
from joblib import Parallel, delayed
import yake

# Initialize YAKE extractor outside the function for better performance
yake_kw = yake.KeywordExtractor(n=2, top=5, windowsSize=100)

def yake_extract_kw(text):
    try:
        # Extracting keywords 
        KeyWords = yake_kw.extract_keywords(text) 

        # Displaying top 5 keywords 
        keywords = ",".join((kw for kw, _ in KeyWords if "qatar" not in kw))
        return keywords
    
    except Exception as e:
        print(f"Error processing text: {text}")
        print(f"Error details: {e}")
        return ""

# https://stackoverflow.com/questions/42220458/what-does-the-delayed-function-do-when-used-with-joblib-in-python
def process_texts_parallel(texts, n_jobs=-1):
    results = Parallel(n_jobs=n_jobs)(delayed(yake_extract_kw)(text) for text in texts)
    return results

# %%
df['yake_kw']=process_texts_parallel(df['cleaned_text'].tolist())

# %%
df.to_csv("qatarairways_tweets_sentiments_with_keywords.csv", index=False)
