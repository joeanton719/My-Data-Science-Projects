# %%
import pandas as pd
from ntscraper import Nitter

# %%
# https://blog.knowledgator.com/twitter-sentiment-analysis-in-python-few-lines-of-code-bdabfe2efcfd

# Define a scraping function that will returns its results in the table. 
def get_tweets(
    query,
    scraper,
    mode: str,
    instance: str,
    size: int=-1,
    since: str=None,
    until: str=None,
    language: str='en') -> pd.DataFrame:
  
  tweets = scraper.get_tweets(query, 
                              mode=mode,
                              to=query,
                              number=size,
                              since=since,
                              until=until,
                              instance=instance,
                              language=language)
  
  
  final_tweets = []
  
  try:
    for tweet in tweets['tweets']:
      
      data = [tweet['link'], 
              tweet['text'], 
              tweet['date'], 
              tweet['stats']['likes'], 
              tweet['stats']['comments']]
      
      final_tweets.append(data)

  except IndexError:
    print("IndexError")
    pass
    
  data = pd.DataFrame(final_tweets, columns = ['link', 'text', 'date', 'Likes', 'Comments'])
  
  return data

# %%
instance="https://nitter.woodland.cafe"

for i, date in enumerate(pd.date_range(start="2022-09-08", end="2022-11-30")):

    print(date)

    # Initialize scraper library
    scraper = Nitter(
        log_level=1, 
        skip_instance_check=True,
        # skip_instance_check=False,
    )

    qrtweets_df = get_tweets(query="qrsupport",
                            instance=instance,
                            scraper=scraper, 
                            mode="term",
                            since=date.strftime('%Y-%m-%d'),
                            until=(date + pd.Timedelta("1d")).strftime('%Y-%m-%d'))

    qrtweets_df.to_csv(f"qrtweets_2022 rest_{i+1}.csv", index=False)
    print()

print()
print("Done!")
# Out:
# 2022-09-08 00:00:00
# 20-Dec-23 11:19:01 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:19:05 - Current stats for qrsupport: 18 tweets, 0 threads...
# 20-Dec-23 11:19:06 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-09 00:00:00
# 20-Dec-23 11:19:16 - Current stats for qrsupport: 20 tweets, 0 threads...
# 20-Dec-23 11:19:21 - Current stats for qrsupport: 26 tweets, 0 threads...
# 20-Dec-23 11:19:22 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-10 00:00:00
# 20-Dec-23 11:19:32 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:19:36 - Current stats for qrsupport: 23 tweets, 0 threads...
# 20-Dec-23 11:19:40 - Current stats for qrsupport: 35 tweets, 0 threads...
# 20-Dec-23 11:19:42 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-11 00:00:00
# 20-Dec-23 11:19:51 - Current stats for qrsupport: 13 tweets, 0 threads...
# 20-Dec-23 11:19:55 - Current stats for qrsupport: 21 tweets, 0 threads...
# 20-Dec-23 11:19:57 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-12 00:00:00
# 20-Dec-23 11:20:07 - Current stats for qrsupport: 12 tweets, 0 threads...
# 20-Dec-23 11:20:11 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:20:14 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-13 00:00:00
# 20-Dec-23 11:20:23 - Current stats for qrsupport: 13 tweets, 0 threads...
# 20-Dec-23 11:20:27 - Current stats for qrsupport: 18 tweets, 0 threads...
# 20-Dec-23 11:20:31 - Current stats for qrsupport: 23 tweets, 0 threads...
# 20-Dec-23 11:20:34 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-14 00:00:00
# 20-Dec-23 11:20:43 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:20:47 - Current stats for qrsupport: 23 tweets, 0 threads...
# 20-Dec-23 11:20:49 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-15 00:00:00
# 20-Dec-23 11:20:58 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:21:00 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-16 00:00:00
# 20-Dec-23 11:21:09 - Current stats for qrsupport: 8 tweets, 0 threads...
# 20-Dec-23 11:21:11 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-17 00:00:00
# 20-Dec-23 11:21:20 - Current stats for qrsupport: 18 tweets, 0 threads...
# 20-Dec-23 11:21:24 - Current stats for qrsupport: 22 tweets, 0 threads...
# 20-Dec-23 11:21:26 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-18 00:00:00
# 20-Dec-23 11:21:36 - Current stats for qrsupport: 9 tweets, 0 threads...
# 20-Dec-23 11:21:37 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-19 00:00:00
# 20-Dec-23 11:21:47 - Current stats for qrsupport: 18 tweets, 0 threads...
# 20-Dec-23 11:21:49 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-20 00:00:00
# 20-Dec-23 11:21:59 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:22:03 - Current stats for qrsupport: 18 tweets, 0 threads...
# 20-Dec-23 11:22:05 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-21 00:00:00
# 20-Dec-23 11:22:15 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:22:16 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-22 00:00:00
# 20-Dec-23 11:22:26 - Current stats for qrsupport: 12 tweets, 0 threads...
# 20-Dec-23 11:22:29 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:22:31 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-23 00:00:00
# 20-Dec-23 11:22:41 - Current stats for qrsupport: 12 tweets, 0 threads...
# 20-Dec-23 11:22:45 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:22:47 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-24 00:00:00
# 20-Dec-23 11:22:57 - Current stats for qrsupport: 7 tweets, 0 threads...
# 20-Dec-23 11:22:58 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-25 00:00:00
# 20-Dec-23 11:23:08 - Current stats for qrsupport: 6 tweets, 0 threads...
# 20-Dec-23 11:23:10 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-26 00:00:00
# 20-Dec-23 11:23:19 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:23:21 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-27 00:00:00
# 20-Dec-23 11:23:31 - Current stats for qrsupport: 13 tweets, 0 threads...
# 20-Dec-23 11:23:33 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-28 00:00:00
# 20-Dec-23 11:23:42 - Current stats for qrsupport: 18 tweets, 0 threads...
# 20-Dec-23 11:23:46 - Current stats for qrsupport: 19 tweets, 0 threads...
# 20-Dec-23 11:23:48 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-29 00:00:00
# 20-Dec-23 11:23:58 - Current stats for qrsupport: 16 tweets, 0 threads...
# 20-Dec-23 11:24:02 - Current stats for qrsupport: 32 tweets, 0 threads...
# 20-Dec-23 11:24:04 - Empty page on https://nitter.woodland.cafe
#
# 2022-09-30 00:00:00
# 20-Dec-23 11:24:13 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:24:15 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-01 00:00:00
# 20-Dec-23 11:24:25 - Current stats for qrsupport: 9 tweets, 0 threads...
# 20-Dec-23 11:24:27 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-02 00:00:00
# 20-Dec-23 11:24:37 - Current stats for qrsupport: 19 tweets, 0 threads...
# 20-Dec-23 11:24:39 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-03 00:00:00
# 20-Dec-23 11:24:49 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:24:53 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:24:55 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-04 00:00:00
# 20-Dec-23 11:25:05 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:25:09 - Current stats for qrsupport: 20 tweets, 0 threads...
# 20-Dec-23 11:25:11 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-05 00:00:00
# 20-Dec-23 11:25:21 - Current stats for qrsupport: 19 tweets, 0 threads...
# 20-Dec-23 11:25:25 - Current stats for qrsupport: 21 tweets, 0 threads...
# 20-Dec-23 11:25:27 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-06 00:00:00
# 20-Dec-23 11:25:37 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:25:41 - Current stats for qrsupport: 23 tweets, 0 threads...
# 20-Dec-23 11:25:43 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-07 00:00:00
# 20-Dec-23 11:25:52 - Current stats for qrsupport: 4 tweets, 0 threads...
# 20-Dec-23 11:25:56 - Current stats for qrsupport: 20 tweets, 0 threads...
# 20-Dec-23 11:26:00 - Current stats for qrsupport: 24 tweets, 0 threads...
# 20-Dec-23 11:26:02 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-08 00:00:00
# 20-Dec-23 11:26:11 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:26:16 - Current stats for qrsupport: 16 tweets, 0 threads...
# 20-Dec-23 11:26:17 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-09 00:00:00
# 20-Dec-23 11:26:27 - Current stats for qrsupport: 16 tweets, 0 threads...
# 20-Dec-23 11:26:31 - Current stats for qrsupport: 18 tweets, 0 threads...
# 20-Dec-23 11:26:33 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-10 00:00:00
# 20-Dec-23 11:26:42 - Current stats for qrsupport: 10 tweets, 0 threads...
# 20-Dec-23 11:26:45 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-11 00:00:00
# 20-Dec-23 11:26:55 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:26:59 - Current stats for qrsupport: 24 tweets, 0 threads...
# 20-Dec-23 11:27:01 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-12 00:00:00
# 20-Dec-23 11:27:11 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:27:15 - Current stats for qrsupport: 31 tweets, 0 threads...
# 20-Dec-23 11:27:17 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-13 00:00:00
# 20-Dec-23 11:27:26 - Current stats for qrsupport: 11 tweets, 0 threads...
# 20-Dec-23 11:27:28 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-14 00:00:00
# 20-Dec-23 11:27:38 - Current stats for qrsupport: 12 tweets, 0 threads...
# 20-Dec-23 11:27:39 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-15 00:00:00
# 20-Dec-23 11:27:49 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:27:53 - Current stats for qrsupport: 18 tweets, 0 threads...
# 20-Dec-23 11:27:55 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-16 00:00:00
# 20-Dec-23 11:28:05 - Current stats for qrsupport: 5 tweets, 0 threads...
# 20-Dec-23 11:28:07 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-17 00:00:00
# 20-Dec-23 11:28:16 - Current stats for qrsupport: 12 tweets, 0 threads...
# 20-Dec-23 11:28:18 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-18 00:00:00
# 20-Dec-23 11:28:28 - Current stats for qrsupport: 16 tweets, 0 threads...
# 20-Dec-23 11:28:29 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-19 00:00:00
# 20-Dec-23 11:28:39 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:28:43 - Current stats for qrsupport: 24 tweets, 0 threads...
# 20-Dec-23 11:28:45 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-20 00:00:00
# 20-Dec-23 11:28:55 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:28:57 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-21 00:00:00
# 20-Dec-23 11:29:06 - Current stats for qrsupport: 8 tweets, 0 threads...
# 20-Dec-23 11:29:08 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-22 00:00:00
# 20-Dec-23 11:29:18 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:29:20 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-23 00:00:00
# 20-Dec-23 11:29:30 - Current stats for qrsupport: 11 tweets, 0 threads...
# 20-Dec-23 11:29:31 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-24 00:00:00
# 20-Dec-23 11:29:41 - Current stats for qrsupport: 8 tweets, 0 threads...
# 20-Dec-23 11:29:43 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-25 00:00:00
# 20-Dec-23 11:29:53 - Current stats for qrsupport: 11 tweets, 0 threads...
# 20-Dec-23 11:29:54 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-26 00:00:00
# 20-Dec-23 11:30:04 - Current stats for qrsupport: 19 tweets, 0 threads...
# 20-Dec-23 11:30:08 - Current stats for qrsupport: 23 tweets, 0 threads...
# 20-Dec-23 11:30:10 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-27 00:00:00
# 20-Dec-23 11:30:20 - Current stats for qrsupport: 19 tweets, 0 threads...
# 20-Dec-23 11:30:22 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-28 00:00:00
# 20-Dec-23 11:30:31 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:30:33 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-29 00:00:00
# 20-Dec-23 11:30:42 - Current stats for qrsupport: 6 tweets, 0 threads...
# 20-Dec-23 11:30:44 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-30 00:00:00
# 20-Dec-23 11:30:53 - Current stats for qrsupport: 4 tweets, 0 threads...
# 20-Dec-23 11:30:55 - Empty page on https://nitter.woodland.cafe
#
# 2022-10-31 00:00:00
# 20-Dec-23 11:31:05 - Current stats for qrsupport: 10 tweets, 0 threads...
# 20-Dec-23 11:31:06 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-01 00:00:00
# 20-Dec-23 11:31:16 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:31:20 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:31:22 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-02 00:00:00
# 20-Dec-23 11:31:32 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:31:36 - Current stats for qrsupport: 16 tweets, 0 threads...
# 20-Dec-23 11:31:38 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-03 00:00:00
# 20-Dec-23 11:31:48 - Current stats for qrsupport: 20 tweets, 0 threads...
# 20-Dec-23 11:31:53 - Current stats for qrsupport: 37 tweets, 0 threads...
# 20-Dec-23 11:31:57 - Current stats for qrsupport: 39 tweets, 0 threads...
# 20-Dec-23 11:31:58 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-04 00:00:00
# 20-Dec-23 11:32:09 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:32:14 - Current stats for qrsupport: 34 tweets, 0 threads...
# 20-Dec-23 11:32:15 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-05 00:00:00
# 20-Dec-23 11:32:25 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:32:30 - Current stats for qrsupport: 24 tweets, 0 threads...
# 20-Dec-23 11:32:32 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-06 00:00:00
# 20-Dec-23 11:32:42 - Current stats for qrsupport: 11 tweets, 0 threads...
# 20-Dec-23 11:32:46 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:32:49 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-07 00:00:00
# 20-Dec-23 11:32:58 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:33:01 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-08 00:00:00
# 20-Dec-23 11:33:10 - Current stats for qrsupport: 6 tweets, 0 threads...
# 20-Dec-23 11:33:14 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:33:17 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-09 00:00:00
# 20-Dec-23 11:33:26 - Current stats for qrsupport: 13 tweets, 0 threads...
# 20-Dec-23 11:33:28 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-10 00:00:00
# 20-Dec-23 11:33:38 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:33:40 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-11 00:00:00
# 20-Dec-23 11:33:50 - Current stats for qrsupport: 19 tweets, 0 threads...
# 20-Dec-23 11:33:55 - Current stats for qrsupport: 24 tweets, 0 threads...
# 20-Dec-23 11:33:58 - Current stats for qrsupport: 25 tweets, 0 threads...
# 20-Dec-23 11:34:03 - Current stats for qrsupport: 26 tweets, 0 threads...
# 20-Dec-23 11:34:07 - Current stats for qrsupport: 30 tweets, 0 threads...
# 20-Dec-23 11:34:09 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-12 00:00:00
# 20-Dec-23 11:34:18 - Current stats for qrsupport: 4 tweets, 0 threads...
# 20-Dec-23 11:34:23 - Current stats for qrsupport: 22 tweets, 0 threads...
# 20-Dec-23 11:34:25 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-13 00:00:00
# 20-Dec-23 11:34:34 - Current stats for qrsupport: 10 tweets, 0 threads...
# 20-Dec-23 11:34:39 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:34:42 - Current stats for qrsupport: 18 tweets, 0 threads...
# 20-Dec-23 11:34:44 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-14 00:00:00
# 20-Dec-23 11:34:54 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:34:56 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-15 00:00:00
# 20-Dec-23 11:35:06 - Current stats for qrsupport: 19 tweets, 0 threads...
# 20-Dec-23 11:35:10 - Current stats for qrsupport: 34 tweets, 0 threads...
# 20-Dec-23 11:35:14 - Current stats for qrsupport: 35 tweets, 0 threads...
# 20-Dec-23 11:35:16 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-16 00:00:00
# 20-Dec-23 11:35:25 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:35:30 - Current stats for qrsupport: 28 tweets, 0 threads...
# 20-Dec-23 11:35:33 - Current stats for qrsupport: 29 tweets, 0 threads...
# 20-Dec-23 11:35:35 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-17 00:00:00
# 20-Dec-23 11:35:45 - Current stats for qrsupport: 16 tweets, 0 threads...
# 20-Dec-23 11:35:50 - Current stats for qrsupport: 21 tweets, 0 threads...
# 20-Dec-23 11:35:52 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-18 00:00:00
# 20-Dec-23 11:36:01 - Current stats for qrsupport: 19 tweets, 0 threads...
# 20-Dec-23 11:36:06 - Current stats for qrsupport: 20 tweets, 0 threads...
# 20-Dec-23 11:36:07 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-19 00:00:00
# 20-Dec-23 11:36:17 - Current stats for qrsupport: 13 tweets, 0 threads...
# 20-Dec-23 11:36:19 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-20 00:00:00
# 20-Dec-23 11:36:28 - Current stats for qrsupport: 20 tweets, 0 threads...
# 20-Dec-23 11:36:33 - Current stats for qrsupport: 34 tweets, 0 threads...
# 20-Dec-23 11:36:35 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-21 00:00:00
# 20-Dec-23 11:36:45 - Current stats for qrsupport: 18 tweets, 0 threads...
# 20-Dec-23 11:36:49 - Current stats for qrsupport: 28 tweets, 0 threads...
# 20-Dec-23 11:36:51 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-22 00:00:00
# 20-Dec-23 11:37:01 - Current stats for qrsupport: 17 tweets, 0 threads...
# 20-Dec-23 11:37:05 - Current stats for qrsupport: 29 tweets, 0 threads...
# 20-Dec-23 11:37:06 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-23 00:00:00
# 20-Dec-23 11:37:16 - Current stats for qrsupport: 19 tweets, 0 threads...
# 20-Dec-23 11:37:20 - Current stats for qrsupport: 24 tweets, 0 threads...
# 20-Dec-23 11:37:21 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-24 00:00:00
# 20-Dec-23 11:37:30 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:37:35 - Current stats for qrsupport: 22 tweets, 0 threads...
# 20-Dec-23 11:37:37 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-25 00:00:00
# 20-Dec-23 11:37:46 - Current stats for qrsupport: 9 tweets, 0 threads...
# 20-Dec-23 11:37:50 - Current stats for qrsupport: 15 tweets, 0 threads...
# 20-Dec-23 11:37:53 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-26 00:00:00
# 20-Dec-23 11:38:02 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:38:04 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-27 00:00:00
# 20-Dec-23 11:38:14 - Current stats for qrsupport: 11 tweets, 0 threads...
# 20-Dec-23 11:38:17 - Current stats for qrsupport: 14 tweets, 0 threads...
# 20-Dec-23 11:38:20 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-28 00:00:00
# 20-Dec-23 11:38:30 - Current stats for qrsupport: 16 tweets, 0 threads...
# 20-Dec-23 11:38:33 - Current stats for qrsupport: 23 tweets, 0 threads...
# 20-Dec-23 11:38:35 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-29 00:00:00
# 20-Dec-23 11:38:45 - Current stats for qrsupport: 11 tweets, 0 threads...
# 20-Dec-23 11:38:46 - Empty page on https://nitter.woodland.cafe
#
# 2022-11-30 00:00:00
# 20-Dec-23 11:38:56 - Current stats for qrsupport: 2 tweets, 0 threads...
# 20-Dec-23 11:39:00 - Current stats for qrsupport: 8 tweets, 0 threads...
# 20-Dec-23 11:39:01 - Empty page on https://nitter.woodland.cafe
#
#
# Done!
